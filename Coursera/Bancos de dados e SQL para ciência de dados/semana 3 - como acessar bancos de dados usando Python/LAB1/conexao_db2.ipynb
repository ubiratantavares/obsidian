# %% [markdown]
# # Tutorial - Conectando-se ao banco de dados Db2 na nuvem usando Python
#
# O objetivo deste tutorial é estabelecer uma conexão com um banco de dados DB2 no banco de dados Cloud a partir de um notebook Python usando a API ibm_db.

# %%
# !pip install ibm-db

# %% [markdown]
# Importe a biblioteca ibm_db Python
# A API ibm_db fornece uma variedade de funções Python úteis para acessar e manipular dados em um banco de dados de servidor de dados IBM®, incluindo funções para se conectar a um banco de dados, preparar e emitir instruções SQL, buscar linhas de conjuntos de resultados, chamar procedimentos armazenados, confirmar e rolar transações de volta, tratamento de erros e recuperação de metadados.
#
# Primeiro importamos a biblioteca ibm_db para nosso aplicativo Python
#
# Execute a seguinte célula clicando dentro dela e, em seguida, pressione as teclas Shift e Enter simultaneamente

# %%
import ibm_db

# %% [markdown]
# Identifique as credenciais de conexão do banco de dados
# A conexão com o dashDB ou banco de dados DB2 requer as seguintes informações:
#
# Nome do motorista
#
# Nome do banco de dados
#
# Nome DNS do host ou endereço IP
#
# Porta do host
#
# Protocolo de conexão
#
# ID de usuário (ou nome de usuário)
#
# Senha do usuário
#
# Aviso: Para obter credenciais, consulte as instruções fornecidas no primeiro Laboratório deste curso.
#
# Agora insira suas credenciais de banco de dados abaixo e execute a célula com Shift + Enter

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "fbd88901-ebdb-4a4f-a32e-9822b9fb237b.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "vrt81820"        # e.g. "abc12345"
dsn_pwd = "Ee9kgt2PafDdlG2F"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "bludb"            # e.g. "BLUDB"
dsn_port = "32731"                # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %% [markdown]
# Crie a conexão de banco de dados DB2
# A API Ibm_db usa o IBM Data Server Driver para ODBC e APIs CLI para se conectar ao IBM DB2 e Informix.
#
# Vamos construir a string de conexão dsn usando as credenciais que você inseriu acima

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

#print the connection string to check correct values are specified
print(dsn)
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=bludb;HOSTNAME=fbd88901-ebdb-4a4f-a32e-9822b9fb237b.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud;PORT=32731;PROTOCOL=TCPIP;UID=vrt81820;PWD=Ee9kgt2PafDdlG2F;SECURITY=SSL;

# %% [markdown]
# Agora estabeleça a conexão com o banco de dados

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  bludb as user:  vrt81820 on host:  fbd88901-ebdb-4a4f-a32e-9822b9fb237b.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud

# %% [markdown]
# Parabéns se você conseguiu se conectar com sucesso. Caso contrário, verifique o erro e tente novamente.

# %%
#Retrieve Metadata for the Database Server
server = ibm_db.server_info(conn)

print ("DBMS_NAME: ", server.DBMS_NAME)
print ("DBMS_VER:  ", server.DBMS_VER)
print ("DB_NAME:   ", server.DB_NAME)
# Out:
# DBMS_NAME:  DB2/LINUXX8664
# DBMS_VER:   11.05.0500
# DB_NAME:    BLUDB

# %%
#Retrieve Metadata for the Database Client / Driver
client = ibm_db.client_info(conn)

print ("DRIVER_NAME:          ", client.DRIVER_NAME) 
print ("DRIVER_VER:           ", client.DRIVER_VER)
print ("DATA_SOURCE_NAME:     ", client.DATA_SOURCE_NAME)
print ("DRIVER_ODBC_VER:      ", client.DRIVER_ODBC_VER)
print ("ODBC_VER:             ", client.ODBC_VER)
print ("ODBC_SQL_CONFORMANCE: ", client.ODBC_SQL_CONFORMANCE)
print ("APPL_CODEPAGE:        ", client.APPL_CODEPAGE)
print ("CONN_CODEPAGE:        ", client.CONN_CODEPAGE)
# Out:
# DRIVER_NAME:           libdb2.a
# DRIVER_VER:            11.05.0500
# DATA_SOURCE_NAME:      BLUDB
# DRIVER_ODBC_VER:       03.51
# ODBC_VER:              03.01.0000
# ODBC_SQL_CONFORMANCE:  EXTENDED
# APPL_CODEPAGE:         1208
# CONN_CODEPAGE:         1208

# %% [markdown]
# Feche a conexão
# Liberamos todos os recursos fechando a conexão. Lembre-se de que é sempre importante fechar as conexões para evitar que conexões não utilizadas ocupem recursos.

# %%
ibm_db.close(conn)
# Out:
# True
